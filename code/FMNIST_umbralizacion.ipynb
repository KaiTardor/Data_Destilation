# %% [markdown]
# # Configuracion del entorno

# %%
import sys
print(sys.executable)
# Out:
# /mnt/homeGPU/haoweihu/env/bin/python

# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (2.0.1+cu118)
# Requirement already satisfied: torchvision in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (0.15.2+cu118)
# Requirement already satisfied: torchaudio in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (2.0.2+cu118)
# Requirement already satisfied: filelock in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (1.13.1)
# Requirement already satisfied: networkx in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (3.1.6)
# Requirement already satisfied: triton==2.0.0 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from triton==2.0.0->torch) (4.0.0)
# Requirement already satisfied: lit in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from triton==2.0.0->torch) (18.1.8)
# Requirement already satisfied: numpy in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: requests in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torchvision) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from requests->torchvision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from requests->torchvision) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from requests->torchvision) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from requests->torchvision) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages (from sympy->torch) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

print("Versión de torch:", torch.__version__)
print("CUDA disponible:", torch.cuda.is_available())
print("Dispositivos CUDA:", torch.cuda.device_count())
print("Nombre de la GPU:", torch.cuda.get_device_name(0) if torch.cuda.device_count() > 0 else "Ninguna GPU")
# Out:
# Versión de torch: 2.3.1
# CUDA disponible: False
# Dispositivos CUDA: 0
# Nombre de la GPU: Ninguna GPU

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="<0>"

# %%
# The first thing we should do is to apply hardware acceleration via GPU. So, we have to go to Editar - Configuracion del Cuaderno - Acelerador por Hardware GPU

import fastbook
fastbook.setup_book()
import fastai
import fastcore
import cv2

print(f'fastcore version {fastcore.__version__} installed')
print(f'fastai version {fastai.__version__} installed')
from nbdev.showdoc import *
from fastai.vision.all import *
# Out:
# fastcore version 1.7.27 installed
# fastai version 2.7.19 installed

# %%
class LeNet(nn.Module):
  def __init__(self, num_classes=10):
    super(LeNet, self).__init__()
    self.conv1 = nn.Conv2d(1, 6, kernel_size=5)
    self.conv2 = nn.Conv2d(6, 16, kernel_size=5)
    self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
    self.fc1 = nn.Linear(16 * 4 * 4, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, num_classes)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = self.pool(x)
    x = F.relu(self.conv2(x))
    x = self.pool(x)
    x = x.view(x.size(0), -1)  # Aplanar la salida
    x = F.relu(self.fc1(x))
    x = F.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
def umbralizacion_tri(img: PILImage):
    return img.quantize(colors=3)

def umbralizacion_bi(img: PILImage):
    return img.quantize(colors=2)

import cv2
def otsu_threshold_transform(img: PILImage):
    img_gray = img.convert("L")
    img_array = np.array(img_gray)
    _, thresholded = cv2.threshold(img_array, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
    return PILImage.create(thresholded)

# %%
from fastai.vision.all import *
from pathlib import Path
import time

def quantize3(train_path, name):

    # Crear el DataBlock para entrenamiento y validación
    dblock = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        splitter=GrandparentSplitter(train_name='training', valid_name='valid'),
        get_y=parent_label,
        item_tfms=[umbralizacion_tri]
    )

    dls = dblock.dataloaders(train_path, bs=64)

    # Obtener el número total de imágenes
    num_train = len(dls.train_ds)
    num_valid = len(dls.valid_ds)

    print(f"Número total de imágenes en entrenamiento: {num_train}")
    print(f"Número total de imágenes en validación: {num_valid}")

    # Obtener la distribución de clases
    class_counts = dls.train_ds.vocab  # Obtiene las clases
    print("\nClases:", class_counts)

    # Inicializar el modelo LeNet con 10 clases
    model = LeNet(num_classes=10)
    
    # Crear el objeto Learner
    learn = Learner(
        dls, 
        model, 
        loss_func=CrossEntropyLossFlat(), 
        metrics=[accuracy, Recall(average='macro'), F1Score(average='macro')], 
        cbs=[EarlyStoppingCallback(monitor='valid_loss', patience=5)]
    )

    # Entrenamiento del modelo con fit_one_cycle
    start_time = time.time()
    learn.fit_one_cycle(30)
    end_time = time.time()
    print(f"\nTiempo de entrenamiento: {end_time - start_time:.2f} segundos")

    # Validación y reporte de métricas
    loss, acc, recall, f1 = learn.validate()
    print(f'Loss: {loss:.4f}')
    print(f'Accuracy: {acc:.4f}')
    print(f"Recall: {recall:.4f}")
    print(f'F1-Score: {f1:.4f}')

    # Exportar el modelo entrenado
    learn.export('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')

    # Crear el DataBlock para los datos de prueba
    test_block = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        get_y=parent_label,
        splitter=IndexSplitter([]),
        item_tfms=[umbralizacion_tri]
    )

    test_dls = test_block.dataloaders("/mnt/homeGPU/haoweihu/code/dataset/original/fashion_mnist/test")

    # Cargar el modelo previamente exportado y remover el callback de EarlyStopping
    learn = load_learner('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')
    learn.remove_cb(EarlyStoppingCallback)

    # Validar con el conjunto de test
    loss, acc, recall, f1 = learn.validate(dl=test_dls.train)
    print(f"Loss: {loss}")
    print(f"Accuracy: {acc}")
    print(f"Recall (macro): {recall}")
    print(f"F1 Score (macro): {f1}")

# %%
def quantize2(train_path, name):

    # Crear el DataBlock para entrenamiento y validación
    dblock = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        splitter=GrandparentSplitter(train_name='training', valid_name='valid'),
        get_y=parent_label,
        item_tfms=[umbralizacion_bi]
    )

    dls = dblock.dataloaders(train_path, bs=64)

    # Obtener el número total de imágenes
    num_train = len(dls.train_ds)
    num_valid = len(dls.valid_ds)

    print(f"Número total de imágenes en entrenamiento: {num_train}")
    print(f"Número total de imágenes en validación: {num_valid}")

    # Obtener la distribución de clases
    class_counts = dls.train_ds.vocab  # Obtiene las clases
    print("\nClases:", class_counts)

    # Inicializar el modelo LeNet con 10 clases
    model = LeNet(num_classes=10)
    
    # Crear el objeto Learner
    learn = Learner(
        dls, 
        model, 
        loss_func=CrossEntropyLossFlat(), 
        metrics=[accuracy, Recall(average='macro'), F1Score(average='macro')], 
        cbs=[EarlyStoppingCallback(monitor='valid_loss', patience=5)]
    )

    # Entrenamiento del modelo con fit_one_cycle
    start_time = time.time()
    learn.fit_one_cycle(30)
    end_time = time.time()
    print(f"\nTiempo de entrenamiento: {end_time - start_time:.2f} segundos")

    # Validación y reporte de métricas
    loss, acc, recall, f1 = learn.validate()
    print(f'Loss: {loss:.4f}')
    print(f'Accuracy: {acc:.4f}')
    print(f"Recall: {recall:.4f}")
    print(f'F1-Score: {f1:.4f}')

    # Exportar el modelo entrenado
    learn.export('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')

    # Crear el DataBlock para los datos de prueba
    test_block = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        get_y=parent_label,
        splitter=IndexSplitter([]),
        item_tfms=[umbralizacion_bi]
    )

    test_dls = test_block.dataloaders("/mnt/homeGPU/haoweihu/code/dataset/original/fashion_mnist/test")

    # Cargar el modelo previamente exportado y remover el callback de EarlyStopping
    learn = load_learner('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')
    learn.remove_cb(EarlyStoppingCallback)

    # Validar con el conjunto de test
    loss, acc, recall, f1 = learn.validate(dl=test_dls.train)
    print(f"Loss: {loss}")
    print(f"Accuracy: {acc}")
    print(f"Recall (macro): {recall}")
    print(f"F1 Score (macro): {f1}")

# %%
def otsu(train_path, name):

    # Crear el DataBlock para entrenamiento y validación
    dblock = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        splitter=GrandparentSplitter(train_name='training', valid_name='valid'),
        get_y=parent_label,
        item_tfms=[otsu_threshold_transform]
    )

    dls = dblock.dataloaders(train_path, bs=64)

    # Obtener el número total de imágenes
    num_train = len(dls.train_ds)
    num_valid = len(dls.valid_ds)

    print(f"Número total de imágenes en entrenamiento: {num_train}")
    print(f"Número total de imágenes en validación: {num_valid}")

    # Obtener la distribución de clases
    class_counts = dls.train_ds.vocab  # Obtiene las clases
    print("\nClases:", class_counts)

    # Inicializar el modelo LeNet con 10 clases
    model = LeNet(num_classes=10)
    
    # Crear el objeto Learner
    learn = Learner(
        dls, 
        model, 
        loss_func=CrossEntropyLossFlat(), 
        metrics=[accuracy, Recall(average='macro'), F1Score(average='macro')], 
        cbs=[EarlyStoppingCallback(monitor='valid_loss', patience=5)]
    )

    # Entrenamiento del modelo con fit_one_cycle
    start_time = time.time()
    learn.fit_one_cycle(30)
    end_time = time.time()
    print(f"\nTiempo de entrenamiento: {end_time - start_time:.2f} segundos")

    # Validación y reporte de métricas
    loss, acc, recall, f1 = learn.validate()
    print(f'Loss: {loss:.4f}')
    print(f'Accuracy: {acc:.4f}')
    print(f"Recall: {recall:.4f}")
    print(f'F1-Score: {f1:.4f}')

    # Exportar el modelo entrenado
    learn.export('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')

    # Crear el DataBlock para los datos de prueba
    test_block = DataBlock(
        blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
        get_items=get_image_files,
        get_y=parent_label,
        splitter=IndexSplitter([]),
        item_tfms=[otsu_threshold_transform]
    )

    test_dls = test_block.dataloaders("/mnt/homeGPU/haoweihu/code/dataset/original/fashion_mnist/test")

    # Cargar el modelo previamente exportado y remover el callback de EarlyStopping
    learn = load_learner('/mnt/homeGPU/haoweihu/code/models/'+name+'.pkl')
td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.594272</td>
#       <td>0.623438</td>
#       <td>0.749815</td>
#       <td>0.749815</td>
#       <td>0.742537</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.588136</td>
#       <td>0.619266</td>
#       <td>0.744167</td>
#       <td>0.744167</td>
#       <td>0.743707</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.575837</td>
#       <td>0.621266</td>
#       <td>0.751944</td>
#       <td>0.751944</td>
#       <td>0.742839</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.575273</td>
#       <td>0.616870</td>
#       <td>0.751481</td>
#       <td>0.751481</td>
#       <td>0.745924</td>
#       <td>00:38</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.577113</td>
#       <td>0.619766</td>
#       <td>0.742037</td>
#       <td>0.742037</td>
#       <td>0.743029</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.560421</td>
#       <td>0.613749</td>
#       <td>0.753611</td>
#       <td>0.753611</td>
#       <td>0.747269</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.563609</td>
#       <td>0.612905</td>
#       <td>0.754907</td>
#       <td>0.754907</td>
#       <td>0.749618</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.566907</td>
#       <td>0.612480</td>
#       <td>0.754444</td>
#       <td>0.754444</td>
#       <td>0.750236</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.564892</td>
#       <td>0.612184</td>
#       <td>0.754537</td>
#       <td>0.754537</td>
#       <td>0.750349</td>
#       <td>00:36</td>
#     </tr>
#   </tbody>
# </table>
# Tiempo de entrenamiento: 1113.93 segundos
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 0.6122
# Accuracy: 0.7545
# Recall: 0.7545
# F1-Score: 0.7503
# /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 5.593207836151123
# Accuracy: 0.6724759340286255
# Recall (macro): 0.6725505432381833
# F1 Score (macro): 0.6496822438838671

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_001/fmnist/example1", "fmnist_dist_otsu_ex1")
# Out:
# Could not do one pass in your dataloader, there is something wrong in it. Please see the stack trace below:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_001/fmnist/example1", "fmnist_dist_otsu_ex1")
#
# Cell In[11], line 12, in otsu(train_path, name)
#       1 def otsu(train_path, name):
#       2
#       3     # Crear el DataBlock para entrenamiento y validación
#       4     dblock = DataBlock(
#       5         blocks=(ImageBlock(cls=PILImageBW), CategoryBlock),
#       6         get_items=get_image_files,
#    (...)
#       9         item_tfms=[otsu_threshold_transform]
#      10     )
# ---> 12     dls = dblock.dataloaders(train_path, bs=64)
#      14     # Obtener el número total de imágenes
#      15     num_train = len(dls.train_ds)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/block.py:159, in DataBlock.dataloaders(self, source, path, verbose, **kwargs)
#     157 dsets = self.datasets(source, verbose=verbose)
#     158 kwargs = {**self.dls_kwargs, **kwargs, 'verbose': verbose}
# --> 159 return dsets.dataloaders(path=path, after_item=self.item_tfms, after_batch=self.batch_tfms, **kwargs)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/core.py:328, in FilteredBase.dataloaders(self, bs, shuffle_train, shuffle, val_shuffle, n, path, dl_type, dl_kwargs, device, drop_last, val_bs, **kwargs)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/core.py:328, in <listcomp>(.0)
#     326 dl = dl_type(self.subset(0), **merge(kwargs,def_kwargs, dl_kwargs[0]))
#     327 def_kwargs = {'bs':bs if val_bs is None else val_bs,'shuffle':val_shuffle,'n':None,'drop_last':False}
# --> 328 dls = [dl] + [dl.new(self.subset(i), **merge(kwargs,def_kwargs,val_kwargs,dl_kwargs[i]))
#     329               for i in range(1, self.n_subsets)]
#     330 return self._dbunch_type(*dls, path=path, device=device)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/core.py:99, in TfmdDL.new(self, dataset, cls, **kwargs)
#      97 if not hasattr(self, '_n_inp') or not hasattr(self, '_types'):
#      98     try:
# ---> 99         self._one_pass()
#     100         res._n_inp,res._types = self._n_inp,self._types
#     101     except Exception as e:
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/core.py:80, in TfmdDL._one_pass(self)
#      79 def _one_pass(self):
# ---> 80     b = self.do_batch([self.do_item(None)])
#      81     if self.device is not None: b = to_device(b, self.device)
#      82     its = self.after_batch(b)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/data/load.py:170, in DataLoader.do_item(self, s)
#     169 def do_item(self, s):
# --> 170     try: return self.after_item(self.create_item(s))
#     171     except SkipItemException: return None
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:210, in Pipeline.__call__(self, o)
# --> 210 def __call__(self, o): return compose_tfms(o, tfms=self.fs, split_idx=self.split_idx)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:160, in compose_tfms(x, tfms, is_enc, reverse, **kwargs)
#     158 for f in tfms:
#     159     if not is_enc: f = f.decode
# --> 160     x = f(x, **kwargs)
#     161 return x
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:83, in Transform.__call__(self, x, **kwargs)
# ---> 83 def __call__(self, x, **kwargs): return self._call('encodes', x, **kwargs)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:93, in Transform._call(self, fn, x, split_idx, **kwargs)
#      91 def _call(self, fn, x, split_idx=None, **kwargs):
#      92     if split_idx!=self.split_idx and self.split_idx is not None: return x
# ---> 93     return self._do_call(getattr(self, fn), x, **kwargs)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:100, in Transform._do_call(self, f, x, **kwargs)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:100, in <genexpr>(.0)
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
#      99     return retain_type(f(x, **kwargs), x, ret)
# --> 100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/transform.py:99, in Transform._do_call(self, f, x, **kwargs)
#      97     if f is None: return x
#      98     ret = f.returns(x) if hasattr(f,'returns') else None
# ---> 99     return retain_type(f(x, **kwargs), x, ret)
#     100 res = tuple(self._do_call(f, x_, **kwargs) for x_ in x)
#     101 return retain_type(res, x)
#
# File /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastcore/dispatch.py:122, in TypeDispatch.__call__(self, *args, **kwargs)
#     120 elif self.inst is not None: f = MethodType(f, self.inst)
#     121 elif self.owner is not None: f = MethodType(f, self.owner)
# --> 122 return f(*args, **kwargs)
#
# Cell In[3], line 10, in otsu_threshold_transform(img)
#       7 def otsu_threshold_transform(img: PILImage):
#       8     #img_gray = img.convert("L")
#       9     img_array = np.array(img)
# ---> 10     _, thresholded = cv2.threshold(img_array, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
#      11     return PILImage.create(thresholded)
#
# NameError: name 'cv2' is not defined

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_001/fmnist/example2", "fmnist_dist_otsu_ex2")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_001/fmnist/example3", "fmnist_dist_otsu_ex3")

# %% [markdown]
# # Distilled 005

# %%
quantize3("/mnt/homeGPU/haoweihu/code/dataset/distilled_005/fmnist/example1", "fmnist_dist5_quant3_ex1")
# Out:
# Número total de imágenes en entrenamiento: 8820
# Número total de imágenes en validación: 10800
#
# Clases: ['Ankle boot', 'Bag', 'Coat', 'Dress', 'Pullover', 'Sandal', 'Shirt', 'Sneaker', 'Trouser']
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.289059</td>
#       <td>2.283030</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:53</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.240986</td>
#       <td>2.212287</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.204696</td>
#       <td>2.199702</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.201362</td>
#       <td>2.201880</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.201580</td>
#       <td>2.200454</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.200686</td>
#       <td>2.202853</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.200670</td>
#       <td>2.198260</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.199835</td>
#       <td>2.199364</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.193053</td>
#       <td>2.180633</td>
#       <td>0.252315</td>
#       <td>0.252315</td>
#       <td>0.155627</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.499562</td>
#       <td>1.251713</td>
#       <td>0.443611</td>
#       <td>0.443611</td>
#       <td>0.368150</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.107367</td>
#       <td>1.009469</td>
#       <td>0.585833</td>
#       <td>0.585833</td>
#       <td>0.558637</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.897887</td>
#       <td>0.843036</td>
#       <td>0.663611</td>
#       <td>0.663611</td>
#       <td>0.636701</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.801504</td>
#       <td>0.766300</td>
#       <td>0.694815</td>
#       <td>0.694815</td>
#       <td>0.680595</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.757514</td>
#       <td>0.731230</td>
#       <td>0.708426</td>
#       <td>0.708426</td>
#       <td>0.703627</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.724508</td>
#       <td>0.724670</td>
#       <td>0.708426</td>
#       <td>0.708426</td>
#       <td>0.703219</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.717928</td>
#       <td>0.697713</td>
#       <td>0.720648</td>
#       <td>0.720648</td>
#       <td>0.713496</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.706464</td>
#       <td>0.702420</td>
#       <td>0.710093</td>
#       <td>0.710093</td>
#       <td>0.696797</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.678160</td>
#       <td>0.687145</td>
#       <td>0.716111</td>
#       <td>0.716111</td>
#       <td>0.696084</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.685330</td>
#       <td>0.677726</td>
#       <td>0.733148</td>
#       <td>0.733148</td>
#       <td>0.731476</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.667965</td>
#       <td>0.669643</td>
#       <td>0.726574</td>
#       <td>0.726574</td>
#       <td>0.723870</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.670096</td>
#       <td>0.670006</td>
#       <td>0.729537</td>
#       <td>0.729537</td>
#       <td>0.724077</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.663962</td>
#       <td>0.662041</td>
#       <td>0.736296</td>
#       <td>0.736296</td>
#       <td>0.731713</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.662363</td>
#       <td>0.654549</td>
#       <td>0.732870</td>
#       <td>0.732870</td>
#       <td>0.728836</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.652492</td>
#       <td>0.652234</td>
#       <td>0.734259</td>
#       <td>0.734259</td>
#       <td>0.730670</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.660394</td>
#       <td>0.649894</td>
#       <td>0.735741</td>
#       <td>0.735741</td>
#       <td>0.732163</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.641901</td>
#       <td>0.653552</td>
#       <td>0.733148</td>
#       <td>0.733148</td>
#       <td>0.726164</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.638748</td>
#       <td>0.647808</td>
#       <td>0.733333</td>
#       <td>0.733333</td>
#       <td>0.728681</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.646727</td>
#       <td>0.645901</td>
#       <td>0.736389</td>
#       <td>0.736389</td>
#       <td>0.731530</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.630322</td>
#       <td>0.645944</td>
#       <td>0.736111</td>
#       <td>0.736111</td>
#       <td>0.731497</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.634309</td>
#       <td>0.645785</td>
#       <td>0.736389</td>
#       <td>0.736389</td>
#       <td>0.731725</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fe9d0dc13a0>
# Traceback (most recent call last):
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fe9d0dc13a0>
# Traceback (most recent call last):
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fe9d0dc13a0>
# Traceback (most recent call last):
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fe9d0dc13a0>
# Traceback (most recent call last):
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     self._shutdown_workers()
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#     if w.is_alive():
#   File "/mnt/homeGPU/haoweihu/env/lib/python3.9/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Tiempo de entrenamiento: 1091.31 segundos
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 0.6458
# Accuracy: 0.7364
# Recall: 0.7364
# F1-Score: 0.7317
# /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 5.975671291351318
# Accuracy: 0.6590544581413269
# Recall (macro): 0.6588764683025735
# F1 Score (macro): 0.6313326581286031

# %%
quantize3("/mnt/homeGPU/haoweihu/code/dataset/distilled_005/fmnist/example2", "fmnist_dist5_quant3_ex2")
# Out:
# Número total de imágenes en entrenamiento: 8820
# Número total de imágenes en validación: 10800
#
# Clases: ['Ankle boot', 'Bag', 'Coat', 'Dress', 'Pullover', 'Sandal', 'Shirt', 'Sneaker', 'Trouser']
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.305458</td>
#       <td>2.297357</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.235032</td>
#       <td>2.207505</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.205864</td>
#       <td>2.203711</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.203284</td>
#       <td>2.201398</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.202165</td>
#       <td>2.198762</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>0.022222</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.180627</td>
#       <td>2.127552</td>
#       <td>0.152130</td>
#       <td>0.152130</td>
#       <td>0.065876</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1
td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.689310</td>
#       <td>0.688164</td>
#       <td>0.734444</td>
#       <td>0.734444</td>
#       <td>0.729568</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.678177</td>
#       <td>0.684197</td>
#       <td>0.730833</td>
#       <td>0.730833</td>
#       <td>0.720170</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.677007</td>
#       <td>0.670028</td>
#       <td>0.739815</td>
#       <td>0.739815</td>
#       <td>0.730627</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.664087</td>
#       <td>0.645942</td>
#       <td>0.750185</td>
#       <td>0.750185</td>
#       <td>0.739392</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.650764</td>
#       <td>0.657929</td>
#       <td>0.755000</td>
#       <td>0.755000</td>
#       <td>0.753841</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.653303</td>
#       <td>0.632375</td>
#       <td>0.761759</td>
#       <td>0.761759</td>
#       <td>0.758538</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.641243</td>
#       <td>0.625422</td>
#       <td>0.760370</td>
#       <td>0.760370</td>
#       <td>0.755283</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.629110</td>
#       <td>0.629155</td>
#       <td>0.760278</td>
#       <td>0.760278</td>
#       <td>0.758596</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.623658</td>
#       <td>0.629483</td>
#       <td>0.752685</td>
#       <td>0.752685</td>
#       <td>0.741227</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.615291</td>
#       <td>0.622918</td>
#       <td>0.755833</td>
#       <td>0.755833</td>
#       <td>0.747526</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.604475</td>
#       <td>0.614920</td>
#       <td>0.758241</td>
#       <td>0.758241</td>
#       <td>0.752849</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.613424</td>
#       <td>0.613819</td>
#       <td>0.763519</td>
#       <td>0.763519</td>
#       <td>0.759531</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.605349</td>
#       <td>0.612960</td>
#       <td>0.765926</td>
#       <td>0.765926</td>
#       <td>0.763920</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.612108</td>
#       <td>0.614306</td>
#       <td>0.765093</td>
#       <td>0.765093</td>
#       <td>0.762421</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.596002</td>
#       <td>0.609270</td>
#       <td>0.764815</td>
#       <td>0.764815</td>
#       <td>0.761988</td>
#       <td>00:37</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.598281</td>
#       <td>0.608667</td>
#       <td>0.767685</td>
#       <td>0.767685</td>
#       <td>0.765424</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.591608</td>
#       <td>0.608465</td>
#       <td>0.766111</td>
#       <td>0.766111</td>
#       <td>0.763165</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.597543</td>
#       <td>0.608452</td>
#       <td>0.765556</td>
#       <td>0.765556</td>
#       <td>0.762575</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# Tiempo de entrenamiento: 1084.76 segundos
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 0.6085
# Accuracy: 0.7656
# Recall: 0.7656
# F1-Score: 0.7626
# /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 3.763075590133667
# Accuracy: 0.6857972741127014
# Recall (macro): 0.685959759351075
# F1 Score (macro): 0.6609049357168979

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_005/fmnist/example1", "fmnist_dist5_otsu_ex1")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_005/fmnist/example2", "fmnist_dist5_otsu_ex2")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_005/fmnist/example3", "fmnist_dist5_otsu_ex3")

# %% [markdown]
# # Distilled 0001

# %%
quantize3("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example1", "fmnist_dist01_quant3_ex1")
# Out:
# Número total de imágenes en entrenamiento: 20160
# Número total de imágenes en validación: 10800
#
# Clases: ['Ankle boot', 'Bag', 'Coat', 'Dress', 'Pullover', 'Sandal', 'Shirt', 'Sneaker', 'Trouser']
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th
td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.416537</td>
#       <td>0.570161</td>
#       <td>0.782593</td>
#       <td>0.782593</td>
#       <td>0.780468</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.392901</td>
#       <td>0.573666</td>
#       <td>0.783611</td>
#       <td>0.783611</td>
#       <td>0.782695</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.398369</td>
#       <td>0.573843</td>
#       <td>0.782222</td>
#       <td>0.782222</td>
#       <td>0.776428</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.383453</td>
#       <td>0.561885</td>
#       <td>0.793611</td>
#       <td>0.793611</td>
#       <td>0.793649</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.402925</td>
#       <td>0.567660</td>
#       <td>0.787870</td>
#       <td>0.787870</td>
#       <td>0.789695</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.376999</td>
#       <td>0.556285</td>
#       <td>0.788889</td>
#       <td>0.788889</td>
#       <td>0.789249</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.363465</td>
#       <td>0.553268</td>
#       <td>0.791944</td>
#       <td>0.791944</td>
#       <td>0.792479</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.392300</td>
#       <td>0.551856</td>
#       <td>0.785926</td>
#       <td>0.785926</td>
#       <td>0.785589</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.373542</td>
#       <td>0.543119</td>
#       <td>0.798611</td>
#       <td>0.798611</td>
#       <td>0.798722</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.376095</td>
#       <td>0.548577</td>
#       <td>0.795093</td>
#       <td>0.795093</td>
#       <td>0.795303</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.368495</td>
#       <td>0.545618</td>
#       <td>0.794815</td>
#       <td>0.794815</td>
#       <td>0.794780</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.358807</td>
#       <td>0.546404</td>
#       <td>0.795370</td>
#       <td>0.795370</td>
#       <td>0.795433</td>
#       <td>00:58</td>
#     </tr>
#   </tbody>
# </table>
# Tiempo de entrenamiento: 1756.08 segundos
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 0.5464
# Accuracy: 0.7954
# Recall: 0.7954
# F1-Score: 0.7954
# /mnt/homeGPU/haoweihu/env/lib/python3.9/site-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Loss: 2.7298073768615723
# Accuracy: 0.7086338400840759
# Recall (macro): 0.7084287154322964
# F1 Score (macro): 0.6864153207063877

# %%
quantize3("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example3", "fmnist_dist01_quant3_ex3")
# Out:
# Número total de imágenes en entrenamiento: 20160
# Número total de imágenes en validación: 10800
#
# Clases: ['Ankle boot', 'Bag', 'Coat', 'Dress', 'Pullover', 'Sandal', 'Shirt', 'Sneaker', 'Trouser']
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/30 00:00&lt;?]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>recall_score</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#       <progress value='0' class='' max='315' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/315 00:00&lt;?]
#     </div>

# %%
quantize2("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example1", "fmnist_dist01_quant2_ex1")

# %%
quantize2("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example2", "fmnist_dist01_quant2_ex2")

# %%
quantize2("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example3", "fmnist_dist01_quant2_ex3")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example1", "fmnist_dist01_otsu_ex1")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example2", "fmnist_dist01_otsu_ex2")

# %%
otsu("/mnt/homeGPU/haoweihu/code/dataset/distilled_0001/fmnist/example3", "fmnist_dist01_otsu_ex3")
